# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-26eea5d44d9a> in <module>()
# ----> 1 import cv2
#       2 import numpy as np
#       3 import pandas as pd
#       4 from matplotlib import pyplot as plt
#
# ImportError: No module named cv2

# %%
img = cv2.imread('/home/dirie/HonoursProject/IPYTHON/data/00001.jpg',0)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-439cc5f2bed0> in <module>()
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
cap = cv2.VideoCapture('jan28.avi')

while(cap.isOpened()):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db70bca1d16c> in <module>()
# ----> 1 cap = cv2.VideoCapture('jan28.avi')
#       2
#       3 while(cap.isOpened()):
#       4     ret, frame = cap.read()
#       5
#
# NameError: name 'cv2' is not defined

# %%
img1 = cv2.medianBlur(img,5)
showImage(img,img1)

# %%
(thresh, im_bw) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
showImage(img,im_bw)

# %%
thresh = cv2.adaptiveThreshold(im_bw,255,1,1,11,2)
thr_bw = cv2.cvtColor(thresh,cv2.COLOR_GRAY2BGR)
thresh_color = cv2.cvtColor(thresh,cv2.COLOR_GRAY2BGR)
# apply some dilation and erosion to join the gaps
thresh = cv2.dilate(thresh,None,iterations = 3)
thresh = cv2.erode(thresh,None,iterations = 2)
showImage(img,thresh)

# %%
def showImage(img,pimg):
    plt.subplot(121),plt.imshow(img),plt.title('Original')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(pimg),plt.title('Image thresold')
    plt.xticks([]), plt.yticks([])
    plt.show()
